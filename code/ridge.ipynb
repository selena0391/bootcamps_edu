# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso, Ridge, RidgeCV
from sklearn.impute import SimpleImputer
from sklearn.metrics import r2_score, mean_squared_error
import seaborn as sns


df = pd.read_csv('./../data/data_normal.csv')

# %%
X = df.drop(['school_name', 'program_name', 'campus_location', 'state', 'reporting_start', 'reporting_end',
       'employed_infield_180days', 'employed_infield_90days', 'not_seeking_infield_90days','graduated_ontime','graduates_included',
       'not_seeking_infield_180days', 'still_seeking_infield_90days',
       'still_seeking_infield_180days', 'median_annual_salary90days',
       'median_annual_salary180days', 'under70K_90days', 'under70K_180days',
       'salary_70K_80K_90days', 'salary_70K_80K_180days',
       'salary_80K_90K_90days', 'salary_80K_90K_180days', 'over90K_90days',
       'over90K_180days'], axis = 1)
y = df['employed_infield_180days']

# %%
imputer = SimpleImputer()
X_imputed = imputer.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_imputed, y, test_size=0.2, random_state=48)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_imputed, y, test_size=0.2, random_state=48)

# %%
model = Ridge(alpha=.005, normalize=True)
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/anastasiyaayala/Desktop/bootcamps_edu/code/ridge.ipynb Cell 5 in 1
# ----> <a href='vscode-notebook-cell:/Users/anastasiyaayala/Desktop/bootcamps_edu/code/ridge.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> model = Ridge(alpha=.005, normalize=True)
#       <a href='vscode-notebook-cell:/Users/anastasiyaayala/Desktop/bootcamps_edu/code/ridge.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> model.fit(X_train, y_train)
#
# TypeError: Ridge.__init__() got an unexpected keyword argument 'normalize'

# %%
y_pred = model.predict(X_test)

# %%
train_score_ridge = model.score(X_train, y_train)
test_score_ridge = model.score(X_test, y_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.5247710238216906

# %%
train_score_ridge
# Out:
# 0.4839358458333872

# %%
test_score_ridge
# Out:
# 0.5247710238216906

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 82.74660262202754

# %%
#root mean_squared_error
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 9.096515960631715

# %%
# Assuming you have already trained your Ridge regression model and obtained predictions
y_actual = np.array(y_test)  # Convert y to a numpy array

plt.scatter(range(len(y_actual)), y_actual, color='blue', label='Actual')
plt.scatter(range(len(y_pred)), y_pred, color='red', label='Predicted')
plt.xlabel('Sample Index')
plt.ylabel('y')
plt.legend()
plt.show()

# %%
plt.scatter(range(len(y_actual)), y_actual, color='blue', label='Actual', marker='o', s=50)
plt.scatter(range(len(y_pred)), y_pred, color='red', label='Predicted', marker='s', s=50)

# %%
plt.scatter(range(len(y_actual)), y_actual, color='blue', label='Actual', alpha=0.7)
plt.scatter(range(len(y_pred)), y_pred, color='red', label='Predicted', alpha=0.7)

# %%
#sns.set()

# %%
plt.scatter(range(len(y_actual)), y_actual, color='steelblue', label='Actual', marker='o', s=50)
plt.scatter(range(len(y_pred)), y_pred, color='salmon', label='Predicted', marker='s', s=50)
plt.legend(fontsize=12)
plt.grid(True, linestyle='--', linewidth=0.5)
plt.title('Actual and Predicted Employment Rate in Ridge model', fontsize=14)
plt.tight_layout()
plt.show()

# %%
# Calculate the differences between actual and predicted values
differences = y_actual - y_pred

# Plot the actual and predicted values
plt.scatter(range(len(y_actual)), y_actual, color='darkblue', label='Actual', marker='o', s=50)
plt.scatter(range(len(y_pred)), y_pred, color='green', label='Predicted', marker='s', s=50)

# Plot lines connecting the actual and predicted values
for i in range(len(y_actual)):
    plt.plot([i, i], [y_actual[i], y_pred[i]], color='gray', linestyle='--', linewidth=0.5)

plt.legend(fontsize=12)
plt.title('Actual and Predicted Employment Rate (Ridge)', fontsize=14)
plt.tight_layout()
plt.savefig("/Users/anastasiyaayala/Desktop/bootcamps_edu/images/image3.png");

# %%
#calculate the differences between actual and predicted values
differences = y_actual - y_pred

# Plot the actual and predicted values
plt.scatter(range(len(y_actual)), y_actual, color='darkblue', label='Actual', marker='o', s=50)


plt.legend(fontsize=12)
plt.title('Actual and Predicted Employment Rate (Ridge)', fontsize=14)
plt.tight_layout()

plt.savefig("/Users/anastasiyaayala/Desktop/bootcamps_edu/images/image1.png")

# %%
#Calculate the differences between actual and predicted values
differences = y_actual - y_pred

# Plot the actual and predicted values
plt.scatter(range(len(y_actual)), y_actual, color='darkblue', label='Actual', marker='o', s=50)
plt.scatter(range(len(y_pred)), y_pred, color='green', label='Predicted', marker='s', s=50)

plt.legend(fontsize=12)
plt.title('Actual and Predicted Employment Rate (Ridge)', fontsize=14)
plt.tight_layout()

plt.savefig("/Users/anastasiyaayala/Desktop/bootcamps_edu/images/image2.png");

# %%
from PIL import Image
import glob
import imageio

# Create a list to store the images
filenames =['/Users/anastasiyaayala/Desktop/bootcamps_edu/images/image1.png','/Users/anastasiyaayala/Desktop/bootcamps_edu/images/image2.png','/Users/anastasiyaayala/Desktop/bootcamps_edu/images/image3.png']
images = []

# Load the images
for filename in filenames:
    img = Image.open(filename)
    images.append(img)

# Read images and append to a list
# for filename in filenames:
#     images.append(imageio.imread(filename))

# Save the images as a GIF
imageio.mimsave('/Users/anastasiyaayala/Desktop/bootcamps_edu/images/animation.gif', images, duration=1)
# Save the images as a GIF
# images[0].save('/Users/anastasiyaayala/Desktop/bootcamps_edu/images/animation.gif',
#                save_all=True,
#                append_images=images[1:],
#                duration=500,
#                loop=0)

# %%
images
# Out:
# [<PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480>,
#  <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480>,
#  <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480>]

# %%
images[0].save("/Users/anastasiyaayala/Desktop/bootcamps_edu/images/my_awesome.gif", format="GIF", append_images=images, save_all=True, duration=100, loop=0)
